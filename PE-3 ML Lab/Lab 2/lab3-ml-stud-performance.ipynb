# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they wo
n't be saved outside of the current session
# Out:
# /kaggle/input/student-performance-multiple-linear-regression/Student_Performance.csv

# %%
data = pd.read_csv('/kaggle/input/student-performance-multiple-linear-regression/Student_Performance.csv')

# %%
data.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
data.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
data.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
data.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_41c56_row0_col0, #T_41c56_row0_col1, #T_41c56_row0_col2, #T_41c56_row0_col3, #T_41c56_row0_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_41c56_row1_col0, #T_41c56_row1_col2, #T_41c56_row1_col3, #T_41c56_row2_col0, #T_41c56_row2_col1, #T_41c56_row2_col2, #T_41c56_row2_col3, #T_41c56_row2_col4, #T_41c56_row3_col0, #T_41c56_row3_col1, #T_41c56_row3_col2, #T_41c56_row3_col3, #T_41c56_row3_col4, #T_41c56_row4_col0, #T_41c56_row4_col1, #T_41c56_row4_col2, #T_41c56_row4_col3, #T_41c56_row4_col4, #T_41c56_row5_col0, #T_41c56_row5_col2, #T_41c56_row5_col3, #T_41c56_row6_col0, #T_41c56_row6_col2, #T_41c56_row6_col3, #T_41c56_row7_col0, #T_41c56_row7_col2, #T_41c56_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_41c56_row1_col1, #T_41c56_row1_col4, #T_41c56_row5_col1, #T_41c56_row5_col4, #T_41c56_row6_col1, #T_41c56_row6_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_41c56_row7_col1, #T_41c56_row7_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# </style>
# <table id="T_41c56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41c56_level0_col0" class="col_heading level0 col0" >Hours Studied</th>
#       <th id="T_41c56_level0_col1" class="col_heading level0 col1" >Previous Scores</th>
#       <th id="T_41c56_level0_col2" class="col_heading level0 col2" >Sleep Hours</th>
#       <th id="T_41c56_level0_col3" class="col_heading level0 col3" >Sample Question Papers Practiced</th>
#       <th id="T_41c56_level0_col4" class="col_heading level0 col4" >Performance Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41c56_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_41c56_row0_col0" class="data row0 col0" >10000.000000</td>
#       <td id="T_41c56_row0_col1" class="data row0 col1" >10000.000000</td>
#       <td id="T_41c56_row0_col2" class="data row0 col2" >10000.000000</td>
#       <td id="T_41c56_row0_col3" class="data row0 col3" >10000.000000</td>
#       <td id="T_41c56_row0_col4" class="data row0 col4" >10000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_41c56_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_41c56_row1_col0" class="data row1 col0" >4.992900</td>
#       <td id="T_41c56_row1_col1" class="data row1 col1" >69.445700</td>
#       <td id="T_41c56_row1_col2" class="data row1 col2" >6.530600</td>
#       <td id="T_41c56_row1_col3" class="data row1 col3" >4.583300</td>
#       <td id="T_41c56_row1_col4" class="data row1 col4" >55.224800</td>
#     </tr>
#     <tr>
#       <th id="T_41c56_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_41c56_row2_col0" class="data row2 col0" >2.589309</td>
#       <td id="T_41c56_row2_col1" class="data row2 col1" >17.343152</td>
#       <td id="T_41c56_row2_col2" class="data row2 col2" >1.695863</td>
#       <td id="T_41c56_row2_col3" class="data row2 col3" >2.867348</td>
#       <td id="T_41c56_row2_col4" class="data row2 col4" >19.212558</td>
#     </tr>
#     <tr>
#       <th id="T_41c56_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_41c56_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_41c56_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_41c56_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_41c56_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_41c56_row3_col4" class="data row3 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_41c56_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_41c56_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_41c56_row4_col1" class="data row4 col1" >54.000000</td>
#       <td id="T_41c56_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_41c56_row4_col3" class="data row4 col3" >2.000000</td>
#       <td id="T_41c56_row4_col4" class="data row4 col4" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_41c56_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_41c56_row5_col0" class="data row5 col0" >5.000000</td>
#       <td id="T_41c56_row5_col1" class="data row5 col1" >69.000000</td>
#       <td id="T_41c56_row5_col2" class="data row5 col2" >7.000000</td>
#       <td id="T_41c56_row5_col3" class="data row5 col3" >5.000000</td>
#       <td id="T_41c56_row5_col4" class="data row5 col4" >55.000000</td>
#     </tr>
#     <tr>
#       <th id="T_41c56_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_41c56_row6_col0" class="data row6 col0" >7.000000</td>
#       <td id="T_41c56_row6_col1" class="data row6 col1" >85.000000</td>
#       <td id="T_41c56_row6_col2" class="data row6 col2" >8.000000</td>
#       <td id="T_41c56_row6_col3" class="data row6 col3" >7.000000</td>
#       <td id="T_41c56_row6_col4" class="data row6 col4" >71.000000</td>
#     </tr>
#     <tr>
#       <th id="T_41c56_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_41c56_row7_col0" class="data row7 col0" >9.000000</td>
#       <td id="T_41c56_row7_col1" class="data row7 col1" >99.000000</td>
#       <td id="T_41c56_row7_col2" class="data row7 col2" >9.000000</td>
#       <td id="T_41c56_row7_col3" class="data row7 col3" >9.000000</td>
#       <td id="T_41c56_row7_col4" class="data row7 col4" >100.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  **Visulizing the data**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %% [markdown]
# **scatter plot: Hours Studied vs Performance Index**

# %%
plt.scatter(data['Hours Studied'], data['Performance Index'])
plt.xlabel('Hours Studied')
plt.ylabel('Performance Index')
plt.title('Hours Studied vs Performance Index')
plt.show()

# %%
sns.barplot(x = 'Extracurricular Activities', y = 'Performance Index', data = data)
plt.xlabel('Extracurricular Activities')
plt.ylabel('Performance Index')
plt.title('Extracurricular Activities vs Performance Index')
plt.show()

# %%
avg = data.groupby('Hours Studied')['Performance Index'].mean()
plt.plot(avg.index, avg.values)
plt.xlabel('Hours Studied')
plt.ylabel('Performance Index')
plt.title('Hours Studied vs Performance Index')
plt.show()

# %%
sns.violinplot(x = 'Sample Question Papers Practiced', y = 'Performance Index', data = data)
plt.xlabel('Sample Question Papers Practiced')
plt.ylabel('Performance Index')
plt.title('Sample Question Papers Practiced vs Performance Index')
plt.show()

# %%
sns.violinplot(
    x='Sample Question Papers Practiced', 
    y='Performance Index', 
    data=data, 
    palette='viridis'  # Add this line
)

plt.xlabel('Sample Question Papers Practiced')
plt.ylabel('Performance Index')
plt.title('Sample Question Papers Practiced vs Performance Index')
plt.show()
# Out:
# /tmp/ipykernel_55/3696437792.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
sns.violinplot(
    x='Sample Question Papers Practiced', 
    y='Performance Index', 
    data=data, 
    hue='Sample Question Papers Practiced', # Links color to the x-axis values
    palette='Set2', 
    legend=False                            # Hides the redundant legend
)
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Performance Index'>

# %%
d = data[['Hours Studied','Previous Scores','Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index']]

corr = d.corr()
#mask = np.triu(np.ones_like(corr, ))
f,ax = plt.subplots(figsize = (5,5))

sns.heatmap(corr)
plt.title('Correlation matrix')
plt.show()

# %%
d = data[['Hours Studied','Previous Scores','Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index']]

corr = d.corr()
mask = np.triu(np.ones_like(corr, ))
f,ax = plt.subplots(figsize = (5,5))

sns.heatmap(corr, annot = True, cmap = 'coolwarm')
plt.title('Correlation matrix')
plt.show()

# %%
sns.pairplot(data[['Hours Studied','Previous Scores','Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index']])
plt.title('Pairwise relationship')
plt.show()
